# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("cibc.csv",header=0,names=['date','desc','credit','payment','card_number'])

# %%
df.drop(['card_number'],axis=1,inplace=True)

# %%
df.head()
# Out:
#          date                                 desc  credit  payment
# 0  2023-08-28        TIM HORTONS #5524 TORONTO, ON    1.67      NaN
# 1  2023-08-28  PITA LITE - KING STREET TORONTO, ON   10.74      NaN
# 2  2023-08-28       TIM HORTONS # 9397 TORONTO, ON    1.67      NaN
# 3  2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    1.14      NaN
# 4  2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    4.11      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 862 entries, 0 to 861
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     862 non-null    object
#  1   desc     862 non-null    object
#  2   credit   802 non-null    float64
#  3   payment  60 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 27.1+ KB

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 862 entries, 0 to 861
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     862 non-null    datetime64[ns]
#  1   desc     862 non-null    object
#  2   credit   802 non-null    float64
#  3   payment  60 non-null     float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 27.1+ KB

# %%
def extract_dates(df):
    df['day']=df['date'].dt.day
    df['month']=df['date'].dt.month
    df['year']=df['date'].dt.year
    df['month_name']=df['date'].dt.month_name()
    df['week_number']=df['date'].dt.isocalendar().week
    return df

# %%
df_d=extract_dates(df)
df_d.head()
# Out:
#         date                                 desc  credit  payment  day  \
# 0 2023-08-28        TIM HORTONS #5524 TORONTO, ON    1.67      NaN   28
# 1 2023-08-28  PITA LITE - KING STREET TORONTO, ON   10.74      NaN   28
# 2 2023-08-28       TIM HORTONS # 9397 TORONTO, ON    1.67      NaN   28
# 3 2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    1.14      NaN   28
# 4 2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    4.11      NaN   28
#
#    month  year month_name  week_number
# 0      8  2023     August           35
# 1      8  2023     August           35
# 2      8  2023     August           35
# 3      8  2023     August           35
# 4      8  2023     August           35

# %%
import regex as re
def extract_name(text):
        if re.search(r'\d', text):# If numbers are present, extract text before any sequence of digits
            result = re.split(r'\s*\d+\s*', text)[0].strip()
            #match=re.search(r'(.+?)#(\d+)', text)
            #print(match.group(1),11232,match.group(2))
#             if match:
#                 result = match.group(1).strip()
            result=result.replace("#","").strip()
        else:# If no numbers are present, extract everything except the last word
            parts = text.split(" ")[:-2]
            result = ' '.join(parts)
        #print(result)
        return(result)

# %%
extract_name(" eleven # 33456")
# Out:
# 'eleven'

# %%
def process_desc(df):
    df['desc']=df['desc'].str.replace("*","",regex=False)
    df['business_name']=df['desc'].apply(extract_name)
    df['store_number'] = df['desc'].str.extract(r'(\d+)')
    df['location']=df['desc'].str.split(" ").str[-2].str.strip(",")
    df['province']=df['desc'].str.split(" ").str[-1].str.strip(" ")
    return df

# %%
df_x=process_desc(df_d)
df_x.head()
# Out:
#         date                                 desc  credit  payment  day  \
# 0 2023-08-28        TIM HORTONS #5524 TORONTO, ON    1.67      NaN   28
# 1 2023-08-28  PITA LITE - KING STREET TORONTO, ON   10.74      NaN   28
# 2 2023-08-28       TIM HORTONS # 9397 TORONTO, ON    1.67      NaN   28
# 3 2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    1.14      NaN   28
# 4 2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    4.11      NaN   28
#
#    month  year month_name  week_number            business_name store_number  \
# 0      8  2023     August           35              TIM HORTONS         5524
# 1      8  2023     August           35  PITA LITE - KING STREET          NaN
# 2      8  2023     August           35              TIM HORTONS         9397
# 3      8  2023     August           35          REXALL PHARMACY         8159
# 4      8  2023     August           35          REXALL PHARMACY         8159
#
#   location province
# 0  TORONTO       ON
# 1  TORONTO       ON
# 2  TORONTO       ON
# 3  TORONTO       ON
# 4  TORONTO       ON

# %%
df_x[df_x['date']=='2023-08-14']
# Out:
#          date                               desc  credit  payment  day  month  \
# 41 2023-08-14  REXALL PHARMACY #8159 TORONTO, ON    4.38      NaN   14      8
# 42 2023-08-14  REXALL PHARMACY #8159 TORONTO, ON    5.79      NaN   14      8
# 43 2023-08-14      TIM HORTONS #5524 TORONTO, ON    1.67      NaN   14      8
# 44 2023-08-14  PAYMENT THANK YOU/PAIEMEN T MERCI     NaN    500.0   14      8
# 45 2023-08-14          FRESHCO #3315 TORONTO, ON    9.22      NaN   14      8
#
#     year month_name  week_number              business_name store_number  \
# 41  2023     August           33            REXALL PHARMACY         8159
# 42  2023     August           33            REXALL PHARMACY         8159
# 43  2023     August           33                TIM HORTONS         5524
# 44  2023     August           33  PAYMENT THANK YOU/PAIEMEN          NaN
# 45  2023     August           33                    FRESHCO         3315
#
#    location province
# 41  TORONTO       ON
# 42  TORONTO       ON
# 43  TORONTO       ON
# 44        T    MERCI
# 45  TORONTO       ON

# %%
## further cleaning 
df_x['province']=df_x['province'].apply(lambda x : x if len(x)==2 else np.nan)
df_x['location']=df_x['location'].apply(lambda x: x if len(x)>=2 else np.nan)

# %%
df_x['location']=df_x['location'].astype(str)
def clean_store(x):
    if len(str(x))>5:
        return np.nan
    elif len(str(x))<=1:
        return np.nan
    else:
        return x
df_x['store_number']=df_x['store_number'].apply(clean_store)

# %%
def remove_numbers(input_string):
    # Use regular expression to remove all numbers
    cleaned_string = re.sub(r'\d+', '', input_string)
    if cleaned_string=="":
        cleaned_string=np.nan
    return cleaned_string
df_x['location']=df_x['location'].apply(remove_numbers)

# %%
df_x.iloc[:10]
# Out:
#         date                                  desc  credit  payment  day  \
# 0 2023-08-28         TIM HORTONS #5524 TORONTO, ON    1.67      NaN   28
# 1 2023-08-28   PITA LITE - KING STREET TORONTO, ON   10.74      NaN   28
# 2 2023-08-28        TIM HORTONS # 9397 TORONTO, ON    1.67      NaN   28
# 3 2023-08-28     REXALL PHARMACY #8159 TORONTO, ON    1.14      NaN   28
# 4 2023-08-28     REXALL PHARMACY #8159 TORONTO, ON    4.11      NaN   28
# 5 2023-08-28     REXALL PHARMACY #8159 TORONTO, ON    1.63      NaN   28
# 6 2023-08-28     PAYMENT THANK YOU/PAIEMEN T MERCI     NaN    300.0   28
# 7 2023-08-28  LinkedIn Pre 8627266946 LINKEDIN.COM   26.91      NaN   28
# 8 2023-08-28         TIM HORTONS #2773 TORONTO, ON    1.67      NaN   28
# 9 2023-08-28     REXALL PHARMACY #8159 TORONTO, ON    1.44      NaN   28
#
#    month  year month_name  week_number              business_name  \
# 0      8  2023     August           35                TIM HORTONS
# 1      8  2023     August           35    PITA LITE - KING STREET
# 2      8  2023     August           35                TIM HORTONS
# 3      8  2023     August           35            REXALL PHARMACY
# 4      8  2023     August           35            REXALL PHARMACY
# 5      8  2023     August           35            REXALL PHARMACY
# 6      8  2023     August           35  PAYMENT THANK YOU/PAIEMEN
# 7      8  2023     August           35               LinkedIn Pre
# 8      8  2023     August           35                TIM HORTONS
# 9      8  2023     August           35            REXALL PHARMACY
#
#   store_number location province
# 0         5524  TORONTO       ON
# 1          NaN  TORONTO       ON
# 2         9397  TORONTO       ON
# 3         8159  TORONTO       ON
# 4         8159  TORONTO       ON
# 5         8159  TORONTO       ON
# 6          NaN      nan      NaN
# 7          NaN      NaN      NaN
# 8         2773  TORONTO       ON
# 9         8159  TORONTO       ON

# %%
df_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 862 entries, 0 to 861
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           862 non-null    datetime64[ns]
#  1   desc           862 non-null    object
#  2   credit         802 non-null    float64
#  3   payment        60 non-null     float64
#  4   day            862 non-null    int64
#  5   month          862 non-null    int64
#  6   year           862 non-null    int64
#  7   month_name     862 non-null    object
#  8   week_number    862 non-null    UInt32
#  9   business_name  862 non-null    object
#  10  store_number   606 non-null    object
#  11  location       859 non-null    object
#  12  province       792 non-null    object
# dtypes: UInt32(1), datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 85.2+ KB

# %%
df_x.loc[df_x['desc']=="PAYMENT THANK YOU/PAIEMEN T MERCI","business_name"]=np.nan
df_x.loc[df_x['desc']=="PAYMENT THANK YOU/PAIEMEN T MERCI","location"]=np.nan

# %%
df_x.loc[df_x['desc']=="CASHBACK/REMISE EN ARGENT","business_name"]=np.nan
df_x.loc[df_x['desc']=="CASHBACK/REMISE EN ARGENT","location"]=np.nan

# %%
## process international transactions properly 
def international_transactions(text):
    if "@" in text:
        text=text.split('@')[0].strip()
        text=text.split()
        location="".join(text[-3])
        name=" ".join(text[:-3])
        return name,location
    else:
        return np.nan

# %%
x=df['desc'].apply(international_transactions)

# %%
x=x[x.notna()]
xt=pd.DataFrame(x)
xt['desc']=xt['desc'].apply(list)
xt['name']=xt['desc'].str[0]
xt['location']=xt['desc'].str[1]
xt
# Out:
#                                     desc                    name   location
# 203       [WH Smith Heathrow T5, London]    WH Smith Heathrow T5     London
# 206  [ATLURI FOODS PRIVATE L, HYDERABAD]  ATLURI FOODS PRIVATE L  HYDERABAD
# 207     [TW COFFEE KORAMANGA, BANGALORE]     TW COFFEE KORAMANGA  BANGALORE
# 208         [APOLLO PHARMACY, HYDERABAD]         APOLLO PHARMACY  HYDERABAD
# 209  [CROSSWORD BOOKSTORES L, HYDERABAD]  CROSSWORD BOOKSTORES L  HYDERABAD
# 210             [PVR LIMITED, HYDERABAD]             PVR LIMITED  HYDERABAD
# 211             [PVR LIMITED, HYDERABAD]             PVR LIMITED  HYDERABAD
# 212           [DOMINOS PIZZA, HYDERABAD]           DOMINOS PIZZA  HYDERABAD
# 213                 [FUNCITY, HYDERABAD]                 FUNCITY  HYDERABAD
# 215    [ERRUMANZIL L AND T 1, HYDERABAD]    ERRUMANZIL L AND T 1  HYDERABAD
# 216                 [LKST453, HYDERABAD]                 LKST453  HYDERABAD
# 218  [BANJARA HILLS RD NO 12, HYDERABAD]  BANJARA HILLS RD NO 12  HYDERABAD
# 220  [REL RETAIL LTD - DIGIT, HYDERABAD]  REL RETAIL LTD - DIGIT  HYDERABAD
# 222          [BOOTS 1979 HEATHROW, AIRP]     BOOTS 1979 HEATHROW       AIRP

# %%
df_test=df_x.copy()

# %%
df_test[df_test['date']=='2023-05-03']
# Out:
#           date                                        desc  credit  payment  \
# 210 2023-05-03  PVR LIMITED HYDERABAD 280.00 INR @ .017071    4.78      NaN
# 211 2023-05-03  PVR LIMITED HYDERABAD 440.00 INR @ .017045    7.50      NaN
#
#      day  month  year month_name  week_number          business_name  \
# 210    3      5  2023        May           18  PVR LIMITED HYDERABAD
# 211    3      5  2023        May           18  PVR LIMITED HYDERABAD
#
#     store_number location province
# 210          280      nan      NaN
# 211          440      nan      NaN

# %%
df_x.loc[xt.index,['business_name']]=xt['name']
df_x.loc[xt.index,['location']]=xt['location']
df_x.loc[xt.index,['store_number']]=np.nan

# %%
df_x[df_x['date']=='2023-05-03']
# Out:
#           date                                        desc  credit  payment  \
# 210 2023-05-03  PVR LIMITED HYDERABAD 280.00 INR @ .017071    4.78      NaN
# 211 2023-05-03  PVR LIMITED HYDERABAD 440.00 INR @ .017045    7.50      NaN
#
#      day  month  year month_name  week_number business_name store_number  \
# 210    3      5  2023        May           18   PVR LIMITED          NaN
# 211    3      5  2023        May           18   PVR LIMITED          NaN
#
#       location province
# 210  HYDERABAD      NaN
# 211  HYDERABAD      NaN

# %%
df_x.iloc[20:40]
# Out:
#          date                                 desc  credit  payment  day  \
# 20 2023-08-22    MCDONALD'S #26052 Q04 TORONTO, ON    6.99      NaN   22
# 21 2023-08-21        TIM HORTONS #2773 TORONTO, ON    1.67      NaN   21
# 22 2023-08-21  PITA LITE - KING STREET TORONTO, ON   10.66      NaN   21
# 23 2023-08-21    REXALL PHARMACY #8159 TORONTO, ON    4.08      NaN   21
# 24 2023-08-21    REXALL PHARMACY #8159 TORONTO, ON    2.06      NaN   21
# 25 2023-08-21    REXALL PHARMACY #8159 TORONTO, ON    4.14      NaN   21
# 26 2023-08-21        TIM HORTONS #5524 TORONTO, ON    1.67      NaN   21
# 27 2023-08-21          PRESTO KING STN TORONTO, ON    3.35      NaN   21
# 28 2023-08-21    REXALL PHARMACY #8159 TORONTO, ON    6.62      NaN   21
# 29 2023-08-21        TIM HORTONS #5524 TORONTO, ON    3.44      NaN   21
# 30 2023-08-21            FRESHCO #3315 TORONTO, ON   23.59      NaN   21
# 31 2023-08-17                MOMO GHAR TORONTO, ON   24.60      NaN   17
# 32 2023-08-17    REXALL PHARMACY #8159 TORONTO, ON    6.42      NaN   17
# 33 2023-08-16        TIM HORTONS #2773 TORONTO, ON    1.67      NaN   16
# 34 2023-08-16    REXALL PHARMACY #8159 TORONTO, ON    2.46      NaN   16
# 35 2023-08-16    REXALL PHARMACY #8159 TORONTO, ON    1.94      NaN   16
# 36 2023-08-15        TIM HORTONS #5524 TORONTO, ON    1.67      NaN   15
# 37 2023-08-15    REXALL PHARMACY #8159 TORONTO, ON    1.63      NaN   15
# 38 2023-08-15        TIM HORTONS #5524 TORONTO, ON    1.67      NaN   15
# 39 2023-08-15    REXALL PHARMACY #8159 TORONTO, ON    1.41      NaN   15
#
#     month  year month_name  week_number            business_name store_number  \
# 20      8  2023     August           34               MCDONALD'S        26052
# 21      8  2023     August           34              TIM HORTONS         2773
# 22      8  2023     August           34  PITA LITE - KING STREET          NaN
# 23      8  2023     August           34          REXALL PHARMACY         8159
# 24      8  2023     August           34          REXALL PHARMACY         8159
# 25      8  2023     August           34          REXALL PHARMACY         8159
# 26      8  2023     August           34              TIM HORTONS         5524
# 27      8  2023     August           34          PRESTO KING STN          NaN
# 28      8  2023     August           34          REXALL PHARMACY         8159
# 29      8  2023     August           34              TIM HORTONS         5524
# 30      8  2023     August           34                  FRESHCO         3315
# 31      8  2023     August           33                MOMO GHAR          NaN
# 32      8  2023     August           33          REXALL PHARMACY         8159
# 33      8  2023     August           33              TIM HORTONS         2773
# 34      8  2023     August           33          REXALL PHARMACY         8159
# 35      8  2023     August           33          REXALL PHARMACY         8159
# 36      8  2023     August           33              TIM HORTONS         5524
# 37      8  2023     August           33          REXALL PHARMACY         8159
# 38      8  2023     August           33              TIM HORTONS         5524
# 39      8  2023     August           33          REXALL PHARMACY         8159
#
#    location province
# 20  TORONTO       ON
# 21  TORONTO       ON
# 22  TORONTO       ON
# 23  TORONTO       ON
# 24  TORONTO       ON
# 25  TORONTO       ON
# 26  TORONTO       ON
# 27  TORONTO       ON
# 28  TORONTO       ON
# 29  TORONTO       ON
# 30  TORONTO       ON
# 31  TORONTO       ON
# 32  TORONTO       ON
# 33  TORONTO       ON
# 34  TORONTO       ON
# 35  TORONTO       ON
# 36  TORONTO       ON
# 37  TORONTO       ON
# 38  TORONTO       ON
# 39  TORONTO       ON

# %%
## final cleaning checks
df_x['business_name']=df_x['business_name'].str.lower().str.strip()
df_x['location']=df_x['location'].str.lower().str.strip()

# %%
df_x[df_x['date']=='2023-05-03']
# Out:
#           date                                        desc  credit  payment  \
# 210 2023-05-03  PVR LIMITED HYDERABAD 280.00 INR @ .017071    4.78      NaN
# 211 2023-05-03  PVR LIMITED HYDERABAD 440.00 INR @ .017045    7.50      NaN
#
#      day  month  year month_name  week_number business_name store_number  \
# 210    3      5  2023        May           18   pvr limited          NaN
# 211    3      5  2023        May           18   pvr limited          NaN
#
#       location province
# 210  hyderabad      NaN
# 211  hyderabad      NaN

# %%
#df_x.to_csv('cibc_cleaned.csv')

# %% [markdown]
# ## Final thoughts
#
# # after analyzing the csv file I found that most of data has been captured as per requirement, however sometimes the desc not being in standard format has been a capture.
#
# # some examples which are still wrong
#
# 1. Location captured as onatario due the nature of desc and logic we applied
# 2. location should be saint john instead of only john (index 827) similar index include 843, 717,718,370
# 3. Online market place such as amazon, linkdin location is captured as the website.
# 4. Same goes with few examples of store number.
# 5. Business names were also captured nicely apart from very few examples.

# %% [markdown]
# # Stuff to clean further
#
# 1. Manual- Naive
# 2. Develop a checker function which can map place in canada to location province
# 3. Merge similar business names into one. e.g. presto autl, presto mobl etc
# 4

# %%
df1=df_x.copy()

# %%
df1=df1[df1['business_name'].notna()]

# %%
df1=df1[df1['business_name'].str.startswith('presto')]
df1['business_name']='presto'
df1
# Out:
#           date                                   desc  credit  payment  day  \
# 27  2023-08-21            PRESTO KING STN TORONTO, ON    3.35      NaN   21
# 48  2023-08-09                PRESTO AUTL TORONTO, ON   20.00      NaN    9
# 63  2023-08-03                PRESTO AUTL TORONTO, ON   20.00      NaN    3
# 68  2023-08-02            PRESTO AJAX RELOAD AJAX, ON   20.00      NaN    2
# 87  2023-07-24                PRESTO AUTL TORONTO, ON   20.00      NaN   24
# 157 2023-06-19                PRESTO AUTL TORONTO, ON   20.00      NaN   19
# 236 2023-04-12                PRESTO AUTL TORONTO, ON   20.00      NaN   12
# 251 2023-04-10            PRESTO KING STN TORONTO, ON    3.35      NaN   10
# 284 2023-03-27                PRESTO MOBL TORONTO, ON   10.00      NaN   27
# 287 2023-03-27    PRESTO KIPLING RELOAD ETOBICOKE, ON   20.00      NaN   27
# 301 2023-03-20     PRESTO WELLSLEY RELOAD TORONTO, ON    5.00      NaN   20
# 316 2023-03-13         PRESTO KING RELOAD TORONTO, ON   20.00      NaN   13
# 336 2023-03-06     PRESTO WELLSLEY RELOAD TORONTO, ON   10.00      NaN    6
# 337 2023-03-06                PRESTO MOBL TORONTO, ON   10.00      NaN    6
# 344 2023-03-06         PRESTO KING RELOAD TORONTO, ON   10.00      NaN    6
# 359 2023-02-28         PRESTO KING RELOAD TORONTO, ON   10.00      NaN   28
# 376 2023-02-21         PRESTO KING RELOAD TORONTO, ON   10.00      NaN   21
# 401 2023-02-14         PRESTO KING RELOAD TORONTO, ON    5.00      NaN   14
# 414 2023-02-08         PRESTO KING RELOAD TORONTO, ON   10.00      NaN    8
# 417 2023-02-06         PRESTO KING RELOAD TORONTO, ON   10.00      NaN    6
# 423 2023-02-06        PRESTO WELLSLEY STN TORONTO, ON    5.00      NaN    6
# 432 2023-01-31         PRESTO KING RELOAD TORONTO, ON   10.00      NaN   31
# 437 2023-01-30         PRESTO KING RELOAD TORONTO, ON   10.00      NaN   30
# 442 2023-01-27      PRESTO SPADINA RELOAD TORONTO, ON   10.00      NaN   27
# 454 2023-01-23         PRESTO KING RELOAD TORONTO, ON   20.00      NaN   23
# 476 2023-01-10         PRESTO KING RELOAD TORONTO, ON   10.00      NaN   10
# 478 2023-01-09   PRESTO SHERBOURNE RELOAD TORONTO, ON   10.00      NaN    9
# 482 2023-01-09                PRESTO MOBL TORONTO, ON   10.00      NaN    9
# 511 2022-12-28  PRESTO UNION STATION RELO TORONTO, ON   10.00      NaN   28
# 515 2022-12-28   PRESTO SHERBOURNE RELOAD TORONTO, ON   10.00      NaN   28
# 550 2022-12-06         PRESTO KING RELOAD TORONTO, ON   10.00      NaN    6
# 551 2022-12-05                PRESTO MOBL TORONTO, ON   10.00      NaN    5
# 564 2022-11-29         PRESTO KING RELOAD TORONTO, ON   20.00      NaN   29
# 568 2022-11-28         PRESTO KING RELOAD TORONTO, ON    5.00      NaN   28
# 570 2022-11-24                PRESTO MOBL TORONTO, ON   10.00      NaN   24
# 577 2022-11-21                PRESTO MOBL TORONTO, ON    5.00      NaN   21
# 713 2022-08-29       PRESTO UNION STN STN TORONTO, ON   16.00      NaN   29
# 714 2022-08-29    PRESTO UNION STN RELOAD TORONTO, ON   10.00      NaN   29
# 719 2022-08-22                PRESTO MOBL TORONTO, ON   10.00      NaN   22
# 749 2022-07-29  PRESTO QUEENS PARK RELOAD TORONTO, ON   20.00      NaN   29
# 756 2022-07-20       PRESTO RUNNYMEDE STN TORONTO, ON    5.00      NaN   20
# 783 2022-06-27         PRESTO USBT RELOAD TORONTO, ON   10.00      NaN   27
# 789 2022-06-14  PRESTO UNION STATION RELO TORONTO, ON    5.00      NaN   14
# 792 2022-06-13        PRESTO ST CLAIR STN TORONTO, ON    5.00      NaN   13
# 801 2022-05-09   PRESTO SHERBOURNE RELOAD TORONTO, ON    5.00      NaN    9
# 805 2022-05-02       PRESTO RUNNYMEDE STN TORONTO, ON    5.00      NaN    2
# 830 2022-03-07                     PRESTO TORONTO, ON   10.00      NaN    7
# 831 2022-03-07        PRESTO WELLSLEY STN TORONTO, ON    5.00      NaN    7
#
#      month  year month_name  week_number business_name store_number  \
# 27       8  2023     August           34        presto          NaN
# 48       8  2023     August           32        presto          NaN
# 63       8  2023     August           31        presto          NaN
# 68       8  2023     August           31        presto          NaN
# 87       7  2023       July           30        presto          NaN
# 157      6  2023       June           25        presto          NaN
# 236      4  2023      April           15        presto          NaN
# 251      4  2023      April           15        presto          NaN
# 284      3  2023      March           13        presto          NaN
# 287      3  2023      March           13        presto          NaN
# 301      3  2023      March           12        presto          NaN
# 316      3  2023      March           11        presto          NaN
# 336      3  2023      March           10        presto          NaN
# 337      3  2023      March           10        presto          NaN
# 344      3  2023      March           10        presto          NaN
# 359      2  2023   February            9        presto          NaN
# 376      2  2023   February            8        presto          NaN
# 401      2  2023   February            7        presto          NaN
# 414      2  2023   February            6        presto          NaN
# 417      2  2023   February            6        presto          NaN
# 423      2  2023   February            6        presto          NaN
# 432      1  2023    January            5        presto          NaN
# 437      1  2023    January            5        presto          NaN
# 442      1  2023    January            4        presto          NaN
# 454      1  2023    January            4        presto          NaN
# 476      1  2023    January            2        presto          NaN
# 478      1  2023    January            2        presto          NaN
# 482      1  2023    January            2        presto          NaN
# 511     12  2022   December           52        presto          NaN
# 515     12  2022   December           52        presto          NaN
# 550     12  2022   December           49        presto          NaN
# 551     12  2022   December           49        presto          NaN
# 564     11  2022   November           48        presto          NaN
# 568     11  2022   November           48        presto          NaN
# 570     11  2022   November           47        presto          NaN
# 577     11  2022   November           47        presto          NaN
# 713      8  2022     August           35        presto          NaN
# 714      8  2022     August           35        presto          NaN
# 719      8  2022     August           34        presto          NaN
# 749      7  2022       July           30        presto          NaN
# 756      7  2022       July           29        presto          NaN
# 783      6  2022       June           26        presto          NaN
# 789      6  2022       June           24        presto          NaN
# 792      6  2022       June           24        presto          NaN
# 801      5  2022        May           19        presto          NaN
# 805      5  2022        May           18        presto          NaN
# 830      3  2022      March           10        presto          NaN
# 831      3  2022      March           10        presto          NaN
#
#       location province
# 27     toronto       ON
# 48     toronto       ON
# 63     toronto       ON
# 68        ajax       ON
# 87     toronto       ON
# 157    toronto       ON
# 236    toronto       ON
# 251    toronto       ON
# 284    toronto       ON
# 287  etobicoke       ON
# 301    toronto       ON
# 316    toronto       ON
# 336    toronto       ON
# 337    toronto       ON
# 344    toronto       ON
# 359    toronto       ON
# 376    toronto       ON
# 401    toronto       ON
# 414    toronto       ON
# 417    toronto       ON
# 423    toronto       ON
# 432    toronto       ON
# 437    toronto       ON
# 442    toronto       ON
# 454    toronto       ON
# 476    toronto       ON
# 478    toronto       ON
# 482    toronto       ON
# 511    toronto       ON
# 515    toronto       ON
# 550    toronto       ON
# 551    toronto       ON
# 564    toronto       ON
# 568    toronto       ON
# 570    toronto       ON
# 577    toronto       ON
# 713    toronto       ON
# 714    toronto       ON
# 719    toronto       ON
# 749    toronto       ON
# 756    toronto       ON
# 783    toronto       ON
# 789    toronto       ON
# 792    toronto       ON
# 801    toronto       ON
# 805    toronto       ON
# 830    toronto       ON
# 831    toronto       ON

# %%
df_x.loc[df1.index,['business_name']]=df1['business_name']

# %%
idx=df_x[df_x['business_name']=='pvr'].index
df_x.loc[idx, ['business_name', 'location']] = ['pvr limited', 'hyderabad']

# %%
#7 ELEVEN STORE #33259
df_x.loc[507,['business_name','store_number']]=['7 eleven',33259]
df_x.loc[227,['business_name']]='tor-relay'

# %%
df1=df_x.copy()
df1=df1[df1['business_name'].notna()]
df1=df1[df1['business_name'].str.startswith('amazon')| df1['business_name'].str.startswith('amzn')]
df_x.loc[df1.index,['business_name',"location"]]=['amazon',np.nan]

# %%
df1=df_x.copy()
df1=df1[df1['business_name'].notna()]
df1=df1[df1['business_name'].str.startswith('eventbrite')]
df_x.loc[df1.index,['business_name']]='eventbrite'

# %%
# df_x.to_csv('cibc_cleaned.csv')

# %% [markdown]
# ## create a mapping for location, business_name and province. Will also allow to do checks

# %%
df_notna=df_x[df_x['province'].notna()]
unq_province=list(set(df_notna['province'].tolist()))
unq_province=sorted(unq_province)
unq_province
province_mapper={}
c=1
for i in unq_province:
    if pd.isna(i)==False:
        province_mapper[i]=c
        c+=1
province_mapper
# Out:
# {'BC': 1, 'NB': 2, 'NS': 3, 'ON': 4}

# %%
df_notna=df_x[df_x['business_name'].notna()]
unq_business=set(df_notna['business_name'].tolist())
unq_business=sorted(unq_business)
name_mapper={}
c=1
for i in unq_business:
    if pd.isna(i)==False:
        name_mapper[i]=c
        c+=1
name_mapper
# Out:
# {'7 eleven': 1,
#  'a&w': 2,
#  "ali's nf": 3,
#  "ali's wraps": 4,
#  'amazon': 5,
#  'ambal trading': 6,
#  'apollo pharmacy': 7,
#  'apple.com/bill': 8,
#  'atluri foods private l': 9,
#  'au pain dore': 10,
#  "balzac's upexpress": 11,
#  'banjara hills rd no 12': 12,
#  'big pita': 13,
#  'bike share (toronto pa': 14,
#  'bike share toronto parkin': 15,
#  'boots 1979 heathrow': 16,
#  'ca wonderland foods': 17,
#  'cacao': 18,
#  "canada's wonderland -b": 19,
#  "canada's wonderland-resal": 20,
#  'chipotle': 21,
#  'city tor. ferry docks-onl': 22,
#  'crossword bookstores l': 23,
#  'd and m catering': 24,
#  'dollarama': 25,
#  'dominos pizza': 26,
#  'errumanzil l and t 1': 27,
#  'eventbrite': 28,
#  'fat bastard burrito': 29,
#  'fido home': 30,
#  'fido mobile': 31,
#  'first choice haircutte': 32,
#  'food basics': 33,
#  'freshco': 34,
#  'funcity': 35,
#  'gopod mobile purchase': 36,
#  'hard hat cafe': 37,
#  'ic costco by instacar halifax': 38,
#  'ideal catering': 39,
#  'indiangradstudentassoc': 40,
#  'ins market': 41,
#  'khao': 42,
#  'lcbo/rao': 43,
#  'linkedin pre': 44,
#  'lkst453': 45,
#  "longo's": 46,
#  'luchi recipe': 47,
#  'lyft ride tue': 48,
#  'madison ave. pub': 49,
#  'mare pizzeria inc.': 50,
#  'matha roti': 51,
#  "mcdonald's": 52,
#  'megabus canada': 53,
#  'metergy/ez-pay': 54,
#  'metergy/ez-pay fee': 55,
#  'metro': 56,
#  'metrolinx - go transit': 57,
#  'metrolinx.com': 58,
#  'momo ghar': 59,
#  'msb main cafe - uoft': 60,
#  "msb tim's - uoft": 61,
#  'oise cafe - uoft': 62,
#  'pita express': 63,
#  'pita lite - king street': 64,
#  'pizza pizza': 65,
#  'poparide': 66,
#  'prenup bar': 67,
#  'presto': 68,
#  'pvr limited': 69,
#  'quesada burritos and taco': 70,
#  'rel retail ltd - digit': 71,
#  'rexall pharmacy': 72,
#  'robarts main cafe - uoft': 73,
#  'rogers': 74,
#  'second cup -': 75,
#  'second cup cafe': 76,
#  'shoppers drug mart': 77,
#  'sid smith-gbh': 78,
#  'sizzler kabab': 79,
#  'sp bunners': 80,
#  'sparkle solutions': 81,
#  'sparkle solutions inc': 82,
#  'sq p': 83,
#  'sq pi co.': 84,
#  'sq pizzeria badiali': 85,
#  'sq swagat dosa hut': 86,
#  'st.lawrence pizza & pasta': 87,
#  'starbucks coffee': 88,
#  'subway': 89,
#  'tandoori flame': 90,
#  'the bombay': 91,
#  'third wave coffee': 92,
#  'tim hortons': 93,
#  'tor-relay': 94,
#  'tw coffee koramanga': 95,
#  'u of t bookstore, koffler': 96,
#  'uncle tetsu canada': 97,
#  'uniqlo canada': 98,
#  'uniqlo canada pos_ca_tec_': 99,
#  'up express union tvm': 100,
#  'up express weston tvm': 101,
#  'veda healthy indian ta': 102,
#  'wh smith heathrow t5': 103,
#  'winners': 104}

# %%
df_x[df_x['business_name']=='banjara hills rd no 12']
# Out:
#           date                                               desc  credit  \
# 218 2023-04-24  BANJARA HILLS RD NO 12 HYDERABAD 746.00 INR @ ...   12.65
#
#      payment  day  month  year month_name  week_number  \
# 218      NaN   24      4  2023      April           17
#
#               business_name store_number   location province
# 218  banjara hills rd no 12          NaN  hyderabad      NaN

# %%
df_notna=df_x[df_x['location'].notna()]
unq_location=set(df_notna['location'].tolist())
unq_location=sorted(unq_location)
location_mapper={}
c=1
for i in unq_location:
    if pd.isna(i)==False:
        location_mapper[i]=c
        c+=1
location_mapper
# Out:
# {'--': 1,
#  'airp': 2,
#  'ajax': 3,
#  'bangalore': 4,
#  'concord': 5,
#  'etobicoke': 6,
#  'hyderabad': 7,
#  'john': 8,
#  'london': 9,
#  'maple': 10,
#  'mid-h': 11,
#  'mississauga': 12,
#  'ontario': 13,
#  'scarborough': 14,
#  'toronto': 15,
#  'vancouver': 16,
#  'vaughan': 17,
#  'york': 18}

# %%
replacement_dict = {
    "--": np.nan,
    "airp": "london",
    "mid-h": "halifax",
    "john": "saint john"
}
df_x['location']=df_x['location'].replace((replacement_dict))

# %%
df_notna=df_x[df_x['location'].notna()]
unq_location=set(df_notna['location'].tolist())
unq_location=sorted(unq_location)
location_mapper={}
c=1
for i in unq_location:
    if pd.isna(i)==False:
        location_mapper[i]=c
        c+=1
location_mapper
# Out:
# {'ajax': 1,
#  'bangalore': 2,
#  'concord': 3,
#  'etobicoke': 4,
#  'halifax': 5,
#  'hyderabad': 6,
#  'london': 7,
#  'maple': 8,
#  'mississauga': 9,
#  'ontario': 10,
#  'saint john': 11,
#  'scarborough': 12,
#  'toronto': 13,
#  'vancouver': 14,
#  'vaughan': 15,
#  'york': 16}

# %%
df_x
# Out:
#           date                                 desc  credit  payment  day  \
# 0   2023-08-28        TIM HORTONS #5524 TORONTO, ON    1.67      NaN   28
# 1   2023-08-28  PITA LITE - KING STREET TORONTO, ON   10.74      NaN   28
# 2   2023-08-28       TIM HORTONS # 9397 TORONTO, ON    1.67      NaN   28
# 3   2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    1.14      NaN   28
# 4   2023-08-28    REXALL PHARMACY #8159 TORONTO, ON    4.11      NaN   28
# ..         ...                                  ...     ...      ...  ...
# 857 2022-01-17            AMBAL TRADING TORONTO, ON   27.28      NaN   17
# 858 2022-01-17            FRESHCO #3879 TORONTO, ON   13.19      NaN   17
# 859 2022-01-14        TIM HORTONS #8431 TORONTO, ON    4.18      NaN   14
# 860 2022-01-11            FRESHCO #3879 TORONTO, ON   18.47      NaN   11
# 861 2022-01-10            AMBAL TRADING TORONTO, ON   25.41      NaN   10
#
#      month  year month_name  week_number            business_name  \
# 0        8  2023     August           35              tim hortons
# 1        8  2023     August           35  pita lite - king street
# 2        8  2023     August           35              tim hortons
# 3        8  2023     August           35          rexall pharmacy
# 4        8  2023     August           35          rexall pharmacy
# ..     ...   ...        ...          ...                      ...
# 857      1  2022    January            3            ambal trading
# 858      1  2022    January            3                  freshco
# 859      1  2022    January            2              tim hortons
# 860      1  2022    January            2                  freshco
# 861      1  2022    January            2            ambal trading
#
#     store_number location province
# 0           5524  toronto       ON
# 1            NaN  toronto       ON
# 2           9397  toronto       ON
# 3           8159  toronto       ON
# 4           8159  toronto       ON
# ..           ...      ...      ...
# 857          NaN  toronto       ON
# 858         3879  toronto       ON
# 859         8431  toronto       ON
# 860         3879  toronto       ON
# 861          NaN  toronto       ON
#
# [862 rows x 13 columns]

# %%
df_location=pd.DataFrame(list(location_mapper.items()), columns=['location', 'code'])
df_business_name=pd.DataFrame(list(name_mapper.items()), columns=['name', 'code'])
df_province=pd.DataFrame(list(province_mapper.items()),columns=['province','code'])

# %%
df_location.head()
# Out:
#     location  code
# 0       ajax     1
# 1  bangalore     2
# 2    concord     3
# 3  etobicoke     4
# 4    halifax     5

# %%
df_business_name.head()
# Out:
#           name  code
# 0     7 eleven     1
# 1          a&w     2
# 2     ali's nf     3
# 3  ali's wraps     4
# 4       amazon     5

# %%
df_province.head()
# Out:
#   province  code
# 0       BC     1
# 1       NB     2
# 2       NS     3
# 3       ON     4

# %%
df_final=df_x.copy()

# %% [markdown]
# ## Develop tables for feature engineerings

# %%
business_cat=df_final['business_name'].value_counts().to_frame("count").reset_index().rename(columns={'index':'name'})
business_cat
# Out:
#                        name  count
# 0           rexall pharmacy    282
# 1               tim hortons    151
# 2                   freshco     77
# 3                    presto     48
# 4                    rogers     18
# ..                      ...    ...
# 99   indiangradstudentassoc      1
# 100               sq pi co.      1
# 101      sq swagat dosa hut      1
# 102                7 eleven      1
# 103              prenup bar      1
#
# [104 rows x 2 columns]

# %%
## Let us create categories. If the count > 100 then very high 
## if >50 & <100 then high
## if >20 <50 then med 
##<20 low
def assign_category(count):
    if count >= 100:
        return 'very high'
    elif count>=50 and count<100:
        return 'high'
    elif count >=20 and count <50:
        return 'med'
    else:
        return 'low'
business_cat['category']=business_cat['count'].apply(assign_category)
label2idx={'very high':1,'high':2,'med':3,'low':4}
business_cat['cat_code']=business_cat['category'].map(label2idx)
business_cat
# Out:
#                        name  count   category  cat_code
# 0           rexall pharmacy    282  very high         1
# 1               tim hortons    151  very high         1
# 2                   freshco     77       high         2
# 3                    presto     48        med         3
# 4                    rogers     18        low         4
# ..                      ...    ...        ...       ...
# 99   indiangradstudentassoc      1        low         4
# 100               sq pi co.      1        low         4
# 101      sq swagat dosa hut      1        low         4
# 102                7 eleven      1        low         4
# 103              prenup bar      1        low         4
#
# [104 rows x 4 columns]

# %%
business_cat['category'].value_counts()
# Out:
# low          100
# very high      2
# high           1
# med            1
# Name: category, dtype: int64

# %%
business_cat[business_cat['category']=='high']
# Out:
#       name  count category  cat_code
# 2  freshco     77     high         2

# %%
business_cat.head(10)
# Out:
#                     name  count   category  cat_code
# 0        rexall pharmacy    282  very high         1
# 1            tim hortons    151  very high         1
# 2                freshco     77       high         2
# 3                 presto     48        med         3
# 4                 rogers     18        low         4
# 5  sparkle solutions inc     14        low         4
# 6            food basics     12        low         4
# 7                 amazon     10        low         4
# 8          ambal trading      9        low         4
# 9            pizza pizza      8        low         4

# %%
## save all df to csv
